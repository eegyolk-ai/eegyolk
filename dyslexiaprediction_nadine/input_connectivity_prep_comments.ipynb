# %% [markdown]
# # Model input connectivity format preparation

# %%
import mne      # toolbox for analyzing and visualizing EEG data
import os       # using operating system dependent functionality (folders)
import pandas as pd # data analysis and manipulation
import numpy as np    # numerical computing (manipulating and performing operations on arrays of data)
import copy     # Can Copy and Deepcopy files so original file is untouched.
from ipywidgets import IntSlider, Output
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
from math import nan
from scipy import stats
from mne_connectivity import spectral_connectivity_epochs
from mne_connectivity.viz import plot_sensors_connectivity
import pyvista 
import mayavi
import vtk

import sys
sys.path.insert(0, '../eegyolk') # path to helper functions
import helper_functions as hf # library useful for eeg and erp data cleaning
#import initialization_functions #library to import data
import epod_helper

# %% [markdown]
# <font color='blue'>
# REVIEW: It should be possible now to install `eegyolk'.  We no longer need to
# manipulate the `sys.path</font>

# %%
metadata = pd.read_csv('metadata.csv', sep=',')

# %%
metadata
# Out:
#     eeg_file  ParticipantID test sex  age_months age_months_days  \
# 0       101a            101    a   m          20           20;22
# 1       101b            101    b   m          23           23;16
# 2       102a            102    a   f          20           20;27
# 3       102b            102    b   f          23           23;16
# 4       103a            103    a   f          20           20;23
# ..       ...            ...  ...  ..         ...             ...
# 173     194a            194    a   f          19            19;0
# 174     194b            194    b   f          22            22;3
# 175     195a            195    a   f          18           18;10
# 176     211a            211    a   m          18           18;27
# 177     212a            212    a   f          16            16;4
#
#     dyslexic_parent Group_AccToParents  \
# 0                 m            At risk
# 1                 m            At risk
# 2               Nee            Control
# 3               Nee            Control
# 4                 m            At risk
# ..              ...                ...
# 173               f            At risk
# 174               f            At risk
# 175               f            At risk
# 176               m            At risk
# 177             Nee            Control
#
#                                               path_eeg  \
# 0    F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 1    F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 2    F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 3    F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 4    F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# ..                                                 ...
# 173  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 174  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 175  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 176  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 177  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
#
#                                             path_epoch  \
# 0    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 1    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 2    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 3    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 4    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# ..                                                 ...
# 173  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 174  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 175  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 176  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 177  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
#
#                                      path_eventmarkers    epoch_file
# 0    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  101a_epo.fif
# 1    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  101b_epo.fif
# 2    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  102a_epo.fif
# 3    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  102b_epo.fif
# 4    F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  103a_epo.fif
# ..                                                 ...           ...
# 173  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  194a_epo.fif
# 174  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  194b_epo.fif
# 175  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  195a_epo.fif
# 176  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  211a_epo.fif
# 177  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  212a_epo.fif
#
# [178 rows x 12 columns]

# %%
drop_files = [
    "113a", "107b (deel 1+2)", "132a", "121b(2)", "113b", "107b (deel 3+4)", "147a",
    "121a", "134a", "143b", "121b(1)", "145b", "152a", "184a", "165a", "151a", "163a",
    "179a","179b", "182b", "186a", "193b",
]

metadata = metadata[~metadata['eeg_file'].isin(drop_files)]
metadata = metadata.drop(metadata[metadata['test'] == "b"].index).reset_index()

# %%
metadata
# Out:
#     index eeg_file  ParticipantID test sex  age_months age_months_days  \
# 0       0     101a            101    a   m          20           20;22
# 1       2     102a            102    a   f          20           20;27
# 2       4     103a            103    a   f          20           20;23
# 3       6     104a            104    a   m          18           18;12
# 4       8     105a            105    a   f          17            17;9
# ..    ...      ...            ...  ...  ..         ...             ...
# 85    171     193a            193    a   f          20            20;2
# 86    173     194a            194    a   f          19            19;0
# 87    175     195a            195    a   f          18           18;10
# 88    176     211a            211    a   m          18           18;27
# 89    177     212a            212    a   f          16            16;4
#
#    dyslexic_parent Group_AccToParents  \
# 0                m            At risk
# 1              Nee            Control
# 2                m            At risk
# 3                f            At risk
# 4                f            At risk
# ..             ...                ...
# 85              mf            At risk
# 86               f            At risk
# 87               f            At risk
# 88               m            At risk
# 89             Nee            Control
#
#                                              path_eeg  \
# 0   F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 1   F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 2   F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 3   F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 4   F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# ..                                                ...
# 85  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 86  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 87  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 88  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
# 89  F:\Stage\ePODIUM\Data\ePodium_projectfolder\Da...
#
#                                            path_epoch  \
# 0   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 1   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 2   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 3   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 4   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# ..                                                ...
# 85  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 86  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 87  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 88  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
# 89  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ep...
#
#                                     path_eventmarkers    epoch_file
# 0   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  101a_epo.fif
# 1   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  102a_epo.fif
# 2   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  103a_epo.fif
# 3   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  104a_epo.fif
# 4   F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  105a_epo.fif
# ..                                                ...           ...
# 85  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  193a_epo.fif
# 86  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  194a_epo.fif
# 87  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  195a_epo.fif
# 88  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  211a_epo.fif
# 89  F:\Stage\ePODIUM\Data\ePodium_projectfolder\ev...  212a_epo.fif
#
# [90 rows x 13 columns]

# %% [markdown]
# def read_filtered_data(metadata):
#     epochs = []
#     for index, file in metadata.iterrows():
#         print(f"Checking out file: {file['epoch_file']}")
#         path = os.path.join(file['path_epoch'], file['epoch_file'])
#         epoch = mne.read_epochs(path, preload=False)
#         epochs.append(epoch)
#     return epochs

# %% [markdown]
# <font color='blue'>Review:  This function is also defined in data_analysis notebook.
# Please put this in a shared module. And below please control output if possible</font>

# %%
epochs = read_filtered_data(metadata)
# Out:
# Checking out file: 101a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\101a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2266 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 102a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\102a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2389 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 103a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\103a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1167 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 104a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\104a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 105a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\105a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2049 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 106a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\106a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1942 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 107a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\107a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2286 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 109a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\109a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2438 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 110a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\110a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2421 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 111a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\111a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 606 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 112a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\112a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 114a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\114a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 115a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\115a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 116a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\116a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2343 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 117a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\117a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 118a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\118a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 119a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\119a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 123a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\123a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 124a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\124a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 125a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\125a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 126a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\126a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 127a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\127a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 128a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\128a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 129a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\129a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 130a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\130a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 131a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\131a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 133a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\133a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 135a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\135a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 136a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\136a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2471 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 137a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\137a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 138a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\138a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 139a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\139a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2461 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 140a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\140a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 141a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\141a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2282 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 142a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\142a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 143a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\143a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 144a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\144a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 145a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\145a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 146a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\146a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 148a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\148a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 149a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\149a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 150a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\150a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 153a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\153a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 154a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\154a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 155a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\155a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 156a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\156a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 157a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\157a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 158a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\158a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 159a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\159a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 160a (2)_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\160a (2)_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 160a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\160a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 161a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\161a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 162a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\162a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 164a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\164a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 166a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\166a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2624 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 167a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\167a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 168a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\168a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 169a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\169a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 170a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\170a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 171a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\171a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 172a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\172a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 173a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\173a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 174a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\174a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 213a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\213a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 214a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\214a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 215a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\215a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 216a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\216a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 217a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\217a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 218a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\218a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2315 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 219a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\219a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 220a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\220a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 175a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\175a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2505 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 176a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\176a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 177a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\177a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 178a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\178a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 180a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\180a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 181a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\181a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 182a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\182a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 183a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\183a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 185a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\185a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 187a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\187a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 188a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\188a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2581 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 190a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\190a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 191a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\191a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2514 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 192a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\192a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 193a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\193a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 194a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\194a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 195a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\195a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 211a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\211a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated
# Checking out file: 212a_epo.fif
# Reading F:\Stage\ePODIUM\Data\ePodium_projectfolder\epochs\212a_epo.fif ...
#     Found the data of interest:
#         t =    -299.80 ...     700.20 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 2440 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# <font color='blue'>This looks like an extended version of `data_connectivity()'
# from data_analysis notebook.  Please put them in the same module and reusethe code in both notebooks.</font>

# %%
def input_connectivity_prep(epochs, metadata):
    # loop over epochs
    dfcon = pd.DataFrame()
    
    for i in range(len(metadata)):
        print(f"Calculating connectivity of file {i} \n", end = '')
        # define values for connectivity
        fmin, fmax = 4., 9.
        sfreq = epochs[i].info['sfreq']  # the sampling frequency
        tmin = 0.0  # exclude the baseline period
        
        # calculate connectivity for all epochs per participant
        con = spectral_connectivity_epochs(
            epochs[i], method='pli', mode='multitaper', fmin=fmin, fmax=fmax,
            faverage=True, tmin=tmin, mt_adaptive=False, n_jobs=1)
        
        # transform connectivity to dataframe 
        epochrow = pd.DataFrame(con.get_data())
        # transpose into row and remove all zero connectivity values
        epochrow = epochrow.loc[~(epochrow == 0).all(axis=1)].transpose()
        epochrow['eeg_file'] = metadata['eeg_file'][i]
        #epochrow['test'] = metadata['test'][i]
        epochrow['Group_AccToParents'] = metadata['Group_AccToParents'][i]
        # append row to total dataframe
        dfcon = dfcon.append(epochrow)
        # we need participand ID
        
    return dfcon

# %%
dfcon = input_connectivity_prep(epochs, metadata)
# REVIEW: Same comment on reducing output and not committing it with the notebook.

# %%
#dfcon = dfcon.loc[dfcon['test'] == 'a']
dfcon = dfcon.drop(['eeg_file'], axis=1)

# %%
