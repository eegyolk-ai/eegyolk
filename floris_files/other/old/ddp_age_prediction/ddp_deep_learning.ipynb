# %% [markdown]
# ## Deep Learning
#
# + Create labels for processed data
# + Create generator because of limited memory
# + Load multiple deep learning models models
# + Train the EEG data and labels on the models
# + Load and save the models
# + Visualise the results and performance
#
# Modified from: https://github.com/epodium/EEG_age_prediction

# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import mne
from IPython.display import clear_output

# PATH_MAIN = os.path.join(main_path, 'researchdrive', 'ePodium (Projectfolder)')
PATH_MAIN = os.path.join('D:', 'EEG Data', 'DDP Surfdrive')
PATH_METADATA = os.path.join(PATH_MAIN, 'metadata')
PATH_PROCESSED = os.path.join(PATH_MAIN, 'processed')
PATH_MODELS = os.path.join(PATH_MAIN, 'models')

dataframe = pd.read_excel(os.path.join(PATH_MAIN, 'DDP_age_labels.xlsx'), index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [1], in <cell line: 15>()
#      12 PATH_PROCESSED = os.path.join(PATH_MAIN, 'processed')
#      13 PATH_MODELS = os.path.join(PATH_MAIN, 'models')
# ---> 15 dataframe = pd.read_excel(os.path.join(PATH_MAIN, 'DDP_age_labels.xlsx'), index_col=0)
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/excel/_base.py:457, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     455 if not isinstance(io, ExcelFile):
#     456     should_close = True
# --> 457     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     458 elif engine and engine != io.engine:
#     459     raise ValueError(
#     460         "Engine should not be specified when passing "
#     461         "an ExcelFile - ExcelFile already has the engine set"
#     462     )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/excel/_base.py:1376, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1374     ext = "xls"
#    1375 else:
# -> 1376     ext = inspect_excel_format(
#    1377         content_or_path=path_or_buffer, storage_options=storage_options
#    1378     )
#    1379     if ext is None:
#    1380         raise ValueError(
#    1381             "Excel file format cannot be determined, you must specify "
#    1382             "an engine manually."
#    1383         )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/excel/_base.py:1250, in inspect_excel_format(content_or_path, storage_options)
#    1247 if isinstance(content_or_path, bytes):
#    1248     content_or_path = BytesIO(content_or_path)
# -> 1250 with get_handle(
#    1251     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1252 ) as handle:
#    1253     stream = handle.handle
#    1254     stream.seek(0)
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#    (...)
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
# --> 795         handle = open(handle, ioargs.mode)
#     796     handles.append(handle)
#     798 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/EEG Data/DDP Surfdrive/DDP_age_labels.xlsx'

# %% [markdown]
# #### Create and Load metadata file of processed data

# %%
excel_filepath = os.path.join(PATH_MAIN, 'DDP_age_labels_processed.xlsx')

if(os.path.exists(excel_filepath)):
    dataframe_processed = pd.read_excel(excel_filepath)
else:
    # Storing each column seperately, before concatinating as DataFrame
    code_list = []
    path_list = []
    file_list = []
    age_group_list = []
    age_days_list = []

    files_path = glob.glob(PATH_PROCESSED + '/*.npy')
    for i, file_path in enumerate(files_path):
        filename = os.path.basename(os.path.splitext(file_path)[0])  
        data = dataframe.loc[dataframe['cnt_file'] == filename]

        code_list.append(data['code'].values[0] )    
        path_list.append(file_path)
        file_list.append(filename)
        age_group_list.append( data['age_group'].values[0])
        age_days_list.append(data['age_days'].values[0])

    dataframe_processed = pd.DataFrame({"code": code_list, 'path': path_list, "file": file_list, 'age_group': age_group_list, 'age_days': age_days_list})
    dataframe_processed.to_excel(excel_filepath, index = True)

# %%
from sklearn.model_selection import train_test_split

subject_ids = sorted(list(set(dataframe_processed["code"].tolist())))
IDs_train, IDs_temp = train_test_split(subject_ids, test_size=0.3, random_state=42)
IDs_test, IDs_val = train_test_split(IDs_temp, test_size=0.5, random_state=42)

# %%
subject_ids = sorted(list(set(dataframe_processed["code"].tolist())))
print(f"{len(subject_ids)} unique subject id's")
# Out:
# 304 unique subject id's

# %%
from dataset_generator import DataGenerator

# %%
train_generator_noise = DataGenerator(list_IDs = IDs_train,
                                      BASE_PATH = PATH_PROCESSED,
                                      metadata = dataframe_processed,
                                      n_average = 30,
                                      batch_size = 10,
                                      gaussian_noise=0.01,
                                      iter_per_epoch = 30,
                                      n_timepoints = 501, 
                                      n_channels=30, 
                                      shuffle=True)

val_generator = DataGenerator(list_IDs = IDs_val,
                              BASE_PATH = PATH_PROCESSED,
                              metadata = dataframe_processed,
                              n_average = 30,
                              batch_size = 10,
                              iter_per_epoch = 100,
                              n_timepoints = 501,
                              n_channels=30,
                              shuffle=True)

# %%
train_generator_noise.__getitem__(0)
# Out:
# D:EEG Data\DDP Surfdrive\processed\126_11_mr_mmn2_25_wk_mmn47_wk_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_11_mc_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\466_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\162_11_mr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\494_11_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\001_23_jc_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\637-479-29m-mc-mmn36.cnt.npy
# (array([[[ 2.12376484e-01,  3.33735747e-02,  1.83864336e-01, ...,
#            3.63006617e-02,  2.19464798e-02,  2.83105898e-02],
#          [ 2.31186848e-01,  6.34548754e-02,  2.05194632e-01, ...,
#            1.51055446e-02,  4.55502839e-02, -4.09207915e-02],
#          [ 2.24586755e-01,  5.29160757e-02,  2.02865850e-01, ...,
#            2.13269079e-02,  1.99130268e-02, -6.34920408e-02],
#          ...,
#          [ 6.38247445e-02,  1.07084180e-01,  6.47480873e-01, ...,
#           -1.15780907e-01, -2.23342328e-01, -3.39567968e-01],
#          [ 7.37314609e-02,  1.08483372e-01,  6.45949453e-01, ...,
#           -1.30336869e-01, -2.85129156e-01, -3.20048528e-01],
#          [ 5.77828149e-02,  7.74539263e-02,  6.26372186e-01, ...,
#           -1.42107016e-01, -3.07350385e-01, -3.18309913e-01]],
#
#         [[ 2.51031182e-02, -8.77178173e-02, -8.16399840e-02, ...,
#            4.27777225e-02,  1.81261858e-01,  1.88736271e-01],
#          [ 3.15925440e-02, -9.07187258e-02, -1.11924316e-01, ...,
#            3.36567883e-02,  1.54416186e-01,  1.72593188e-01],
#          [ 3.61728034e-02, -1.03705284e-01, -1.11801015e-01, ...,
#            5.25502563e-02,  1.55544291e-01,  1.86167820e-01],
#          ...,
#          [-5.08157244e-01, -4.88251975e-02, -2.70925165e-01, ...,
#            1.65513207e-01,  3.00268202e-01,  2.01018830e-01],
#          [-5.04899991e-01, -5.21487896e-02, -2.49768303e-01, ...,
#            1.68797652e-01,  3.19862738e-01,  2.12102544e-01],
#          [-4.90494999e-01, -4.52885790e-02, -2.51128390e-01, ...,
#            1.75631557e-01,  3.30305685e-01,  2.18019276e-01]],
#
#         [[ 2.12233023e-02,  9.67309893e-02,  1.72363221e-02, ...,
#           -2.85411467e-01, -1.90425423e-01, -1.75634607e-01],
#          [ 2.65402334e-02,  1.04664186e-01,  5.39137492e-02, ...,
#           -2.33434266e-01, -1.56049321e-01, -1.50999835e-01],
#          [ 4.04798341e-02,  1.34101043e-01,  5.40215894e-02, ...,
#           -1.97836728e-01, -1.28193840e-01, -1.05867279e-01],
#          ...,
#          [ 3.13725851e-01,  3.68771564e-01,  4.12386051e-01, ...,
#            9.97766410e-02,  3.90880862e-01,  2.38405593e-01],
#          [ 3.33743933e-01,  3.71395924e-01,  4.46088948e-01, ...,
#            7.93077820e-02,  3.72405799e-01,  2.28270506e-01],
#          [ 3.48439302e-01,  3.96809051e-01,  4.60203889e-01, ...,
#            4.57795787e-02,  3.70960681e-01,  2.05935183e-01]],
#
#         ...,
#
#         [[ 1.18732786e-01,  1.77687386e-01,  1.49492030e-01, ...,
#            7.00477774e-02,  5.36057302e-02,  7.29915114e-02],
#          [ 9.71243917e-02,  1.72261829e-01,  1.63348390e-01, ...,
#            7.68563572e-02,  9.69951165e-02,  6.07801035e-02],
#          [ 1.22699408e-01,  1.44984317e-01,  1.54051457e-01, ...,
#            6.99186432e-02,  7.58289988e-02,  7.81352501e-02],
#          ...,
#          [ 2.58137008e-01,  6.45205160e-01,  1.81819031e-01, ...,
#            4.67091788e-02, -3.01970151e-02,  5.86787300e-02],
#          [ 2.62847679e-01,  6.33387252e-01,  2.22100553e-01, ...,
#            3.23859244e-02, -2.59373909e-02,  3.06875611e-02],
#          [ 2.56227757e-01,  6.41017079e-01,  2.20786982e-01, ...,
#            5.25690735e-02, -5.20614892e-02,  2.76522458e-02]],
#
#         [[ 1.97324506e-02,  1.13483423e-01, -5.02070699e-03, ...,
#           -1.06265952e-01, -1.42904952e-01, -2.01733252e-01],
#          [ 1.16888096e-02,  1.11371314e-01, -3.05675221e-02, ...,
#           -9.77396027e-02, -1.65152735e-01, -2.03016542e-01],
#          [-9.30979351e-03,  6.66082407e-02, -3.40376852e-02, ...,
#           -9.70952254e-02, -1.51113691e-01, -1.74929666e-01],
#          ...,
#          [ 1.30605510e-01,  1.68484315e-01,  2.35872682e-01, ...,
#            1.50483117e-02, -1.14219392e-01, -1.10788718e-01],
#          [ 1.32495161e-01,  2.13365179e-01,  2.36602223e-01, ...,
#            2.01806080e-02, -1.33424610e-01, -7.29943923e-02],
#          [ 1.61203087e-01,  1.93576983e-01,  2.60506968e-01, ...,
#            2.14977796e-02, -9.35708919e-02, -8.79052809e-02]],
#
#         [[ 5.75964996e-02, -3.98786608e-03,  2.75434371e-03, ...,
#           -4.07296074e-01, -3.10926502e-01, -3.94085471e-01],
#          [ 6.19161505e-02, -1.52327324e-02,  6.47906837e-04, ...,
#           -3.84869753e-01, -2.79850893e-01, -3.64947547e-01],
#          [ 4.77713547e-02, -2.52705134e-02, -1.20302094e-02, ...,
#           -3.75899409e-01, -2.74630162e-01, -3.68842134e-01],
#          ...,
#          [ 7.38650386e-02,  1.60362844e-01,  1.62034047e-01, ...,
#           -8.29993231e-02,  1.89466445e-02, -1.16382324e-01],
#          [ 9.99212821e-02,  1.66922075e-01,  1.78310698e-01, ...,
#           -6.29652968e-02,  6.41914236e-05, -1.19764458e-01],
#          [ 1.08369032e-01,  1.48541918e-01,  1.82122525e-01, ...,
#           -8.74082710e-02,  3.37487754e-04, -1.17515253e-01]]]),
#  array([[ 698],
#         [ 331],
#         [1051],
#         [1046],
#         [ 880],
#         [ 844],
#         [ 323],
#         [ 330],
#         [ 691],
#         [ 329]]))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Input, Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, BatchNormalization, Dense, Conv1D, LeakyReLU, AveragePooling1D, Flatten, Reshape, MaxPooling1D
from tensorflow.keras.optimizers import Adam, Adadelta, SGD
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError
import time

n_timesteps = 501
n_features = 30 
n_outputs = 1

input_shape = (n_timesteps, n_features)

# %%
def evaluate_model(model):
    """ Evaluates the model """
    model.evaluate(train_generator_noise)
    model.evaluate(val_generator)
    model.evaluate(test_generator) 
    
def print_few_predictions(model):
    """ Prints a few predictions, as a sanity check """
    x_test, y_test = test_generator.__getitem__(0)

    print(model.predict(x_test))
    print(y_test)
    
def plot_loss(history):
    """ Plots the MSE, RMSE, and MAE loss for the training and validation data over time """
    
    # %matplotlib inline
    
    fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(12,12), dpi=200)

    ax1.plot(history.history['loss'], label='training data')  
    min_loss = min(history.history['val_loss'])
    val_plot1 = ax1.plot(history.history['val_loss'], label='validation data')
    ax1.axhline(y = min_loss, color = val_plot1[0].get_color(), linestyle = '--') 
    x0,x1 = ax1.get_xlim()
    ax1.text(x1, min_loss, "{:.2f}".format(min_loss), ha='left', va='center')
    ax1.set_title('MSE loss')
    ax1.set_ylabel("MSE")
    ax1.set_xlabel("epochs")
    ax1.legend()

    ax2.plot(history.history['root_mean_squared_error'], label='training data')
    min_loss = min(history.history['val_root_mean_squared_error'])
    val_plot2 = ax2.plot(history.history['val_root_mean_squared_error'], label='validation data')
    ax2.axhline(y = min_loss, color = val_plot2[0].get_color(), linestyle = '--') 
    x0,x1 = ax2.get_xlim()
    ax2.text(x1, min_loss, "{:.2f}".format(min_loss), ha='left', va='center')
    ax2.set_title('RMSE loss')
    ax2.set_ylabel("RMSE")
    ax2.set_xlabel("epochs")
    ax2.legend()
    
    ax3.plot(history.history['mean_absolute_error'], label='training data')    
    min_loss = min(history.history['val_mean_absolute_error'])
    val_plot3 = ax3.plot(history.history['val_mean_absolute_error'], label='validation data')
    ax3.axhline(y = min_loss, color = val_plot3[0].get_color(), linestyle = '--') 
    x0,x1 = ax3.get_xlim()
    ax3.text(x1, min_loss, "{:.2f}".format(min_loss), ha='left', va='center')
    ax3.set_title('MAE loss')
    ax3.set_ylabel("MAE")
    ax3.set_xlabel("epochs")
    ax3.legend()

# %%
def fully_connected_model():
    """ Returns the fully connected model from Ismail Fawaz et al. (2019). """

    input_layer = keras.layers.Input(input_shape)

    input_layer_flattened = keras.layers.Flatten()(input_layer)

    layer_1 = keras.layers.Dropout(0.1)(input_layer_flattened)
    layer_1 = keras.layers.Dense(500, activation='relu')(layer_1)

    layer_2 = keras.layers.Dropout(0.2)(layer_1)
    layer_2 = keras.layers.Dense(500, activation='relu')(layer_2)

    layer_3 = keras.layers.Dropout(0.2)(layer_2)
    layer_3 = keras.layers.Dense(500, activation='relu')(layer_3)

    output_layer = keras.layers.Dropout(0.3)(layer_3)
    output_layer = keras.layers.Dense(1)(output_layer)

    model = keras.models.Model(inputs=input_layer, outputs=output_layer)

    return model

# %%
model = fully_connected_model()

optimizer = Adadelta(learning_rate=0.01)    
              
model.compile(loss='mean_squared_error', 
              optimizer=optimizer, 
              metrics=[RootMeanSquaredError(), MeanAbsoluteError()])

# 01 seems to be incorrect (makes too many predictions, changed model)
# Fully_connected_regressor_01: MSE, Adadelta, N_average=30, 5000 epochs, ES=1000, RLR=200, gaussian=0.01
# Fully_connected_regressor_02: MSE, Adadelta, N_average=30, 5000 epochs, ES=1000, RLR=200, gaussian=0.01
output_filename = 'Fully_connected_regressor_FINAL_LOCAL'
output_file = os.path.join(PATH_MODELS, output_filename)

checkpointer = ModelCheckpoint(filepath = output_file + ".hdf5", monitor='val_loss', verbose=1, save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss', patience=1200, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=200, min_lr=0.0001, verbose=1)

# %%
# %%time

from dataset_generator import DataGenerator
epochs = 5000

# fit network
history = model.fit(x=train_generator_noise,
                    validation_data=val_generator,
                    epochs=epochs, 
                    callbacks=[checkpointer, earlystopper, reduce_lr])
# Out:
# D:EEG Data\DDP Surfdrive\processed\126_11_mr_mmn2_25_wk_mmn47_wk_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_11_mc_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\466_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\162_11_mr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\494_11_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\001_23_jc_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\637-479-29m-mc-mmn36.cnt.npy
# Epoch 1/5000
# D:EEG Data\DDP Surfdrive\processed\015_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_35_jd_mmn36_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\173_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\118_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\141_17_jr_mmn58.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\126_17_mr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\017_23_jc_mmn36_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\324_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\333_11_jc_mmn_25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\623-321-29m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\128_41_jr_mmn36_wk.cnt.npy
#   1/144 [..............................] - ETA: 7:01 - loss: 741721.6875 - root_mean_squared_error: 861.2327 - mean_absolute_error: 814.0049D:EEG Data\DDP Surfdrive\processed\018_11_mc_mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\623-321-23m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\475_41_jd_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\429_35_md_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\455_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\481_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\015_41_jc_mmn39_380_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\325_11_mc_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\617-289-23m-mc-mmn25-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\317_29_mc_mmn36_wk.cnt.npy
#   2/144 [..............................] - ETA: 5:57 - loss: 790432.6250 - root_mean_squared_error: 889.0628 - mean_absolute_error: 833.0466D:EEG Data\DDP Surfdrive\processed\450_41_md_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\009_29_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\134_11_mr_mmn36_wk_mmn25_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\003_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_23_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\612-486-23m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\403_47_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\712-074-29m-mr-mmn36-mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\702-074-23m-jr-mmn25.cnt.npy
#   3/144 [..............................] - ETA: 5:38 - loss: 808042.3750 - root_mean_squared_error: 898.9117 - mean_absolute_error: 846.2521D:EEG Data\DDP Surfdrive\processed\019_41_mc_mmn39_380_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\034_17_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\755-471-23m-mr-mmn36-3.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\309_35_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\475_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\162_11_mr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\130_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\471_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_41_jr_mmn39_380_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_17_jc_mmn25_wk.cnt.npy
#   4/144 [..............................] - ETA: 5:32 - loss: 800050.7500 - root_mean_squared_error: 894.4556 - mean_absolute_error: 842.9457D:EEG Data\DDP Surfdrive\processed\473_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\102_47_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_11_md_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_41_mr_mmn36_1_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\702-074-23m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_11_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\344_29_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\457_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\618-163-11m-jc-mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\328_23_jc_mmn36_wk.cnt.npy
#   5/144 [>.............................] - ETA: 5:38 - loss: 763456.0000 - root_mean_squared_error: 873.7597 - mean_absolute_error: 812.4399D:EEG Data\DDP Surfdrive\processed\414_41_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\478_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\433_41_jd_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\488_11_jd_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\118_47_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_11_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\433_23_jd_mmn236_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_17_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\034_17_mc_mmn36.cnt.npy
#   6/144 [>.............................] - ETA: 5:27 - loss: 770122.6250 - root_mean_squared_error: 877.5663 - mean_absolute_error: 813.1364D:EEG Data\DDP Surfdrive\processed\011_23_jc_mmn25_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\497_11_jd_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\002_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\005_11_jc_mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_17_jr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\118_23_mr_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\144_23_jr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_11_jr_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\033_11_mc_mmn_25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\124_11_jr_mmn36_slp_mmn25_slp_mmn47_slp_mmn58_slp.cnt.npy
#   7/144 [>.............................] - ETA: 5:26 - loss: 710790.1250 - root_mean_squared_error: 843.0837 - mean_absolute_error: 775.4913D:EEG Data\DDP Surfdrive\processed\346_11_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\445_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\001_47_jc_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\324_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\714-082-23m-mr-mmn25-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\104_41_jr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\109_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\414_11_jd_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\019_41_mc_mmn39_1500_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\151_11_mr_mmn36_slp_mmn25_slp_mmn47_slp_mmn58_slp.cnt.npy
#   8/144 [>.............................] - ETA: 5:21 - loss: 719474.4375 - root_mean_squared_error: 848.2184 - mean_absolute_error: 777.9537D:EEG Data\DDP Surfdrive\processed\307_29_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\179_17_mr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\613-176-11m-mc-mmn2-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\624-373-23m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\731-197-23m-jr-mmn36dummy-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\471_11_md_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\344_29_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\443_11_jd_mmn_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\170_17_mr_mmn_36_wk.cnt.npy
#   9/144 [>.............................] - ETA: 5:20 - loss: 675812.0000 - root_mean_squared_error: 822.0779 - mean_absolute_error: 750.2354D:EEG Data\DDP Surfdrive\processed\001_23_jc_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\344_11_jc_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\414_41_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\154_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\130_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_23_jc_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\018_11_mc_mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\413_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\724-116-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\324_41_jc_mmn39_wk.cnt.npy
#  10/144 [=>............................] - ETA: 5:17 - loss: 663179.7500 - root_mean_squared_error: 814.3585 - mean_absolute_error: 744.3185D:EEG Data\DDP Surfdrive\processed\488_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\428_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\165_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\471_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\029_17_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\173_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\438_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\415_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_11_jd_mmn_58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_2_wk.cnt.npy
#  11/144 [=>............................] - ETA: 5:14 - loss: 661767.4375 - root_mean_squared_error: 813.4909 - mean_absolute_error: 746.0654D:EEG Data\DDP Surfdrive\processed\488_11_jd_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\036_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_11_jr_mmn47_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\309_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\466_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\746-438-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_17_jr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\435_23_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\481_29_jd_mmn36_wk.cnt.npy
#  12/144 [=>............................] - ETA: 5:12 - loss: 643213.6875 - root_mean_squared_error: 802.0060 - mean_absolute_error: 735.6249D:EEG Data\DDP Surfdrive\processed\105_47_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\435_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_35_mr_mmnsweep.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\141_17_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_11_jc_mmn_25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\632-399-11m-jc-mmn47-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_11_mc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\011_35_jc_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\430_35_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_17_jr_mmn36.cnt.npy
#  13/144 [=>............................] - ETA: 5:06 - loss: 653269.8125 - root_mean_squared_error: 808.2511 - mean_absolute_error: 740.3340D:EEG Data\DDP Surfdrive\processed\642-485-11m-jc-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\420_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\171_11_jr_mmn36_wk_mmn25_wk_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\039_41_jc_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_11_jd_mmn_backwards_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\702-071-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\612-486-11m-jc-mmn-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\304_17_mc_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\309_17_jc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\717-111-23m-mr-mmn36-dummy-waak.cnt.npy
#  14/144 [=>............................] - ETA: 5:04 - loss: 640371.8750 - root_mean_squared_error: 800.2324 - mean_absolute_error: 730.4333D:EEG Data\DDP Surfdrive\processed\613-176-11m-mc-mmn2-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\712-074-23m-mr-mmn25-mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_35_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\348_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\144_17_jr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\617-289-29m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\620-313-11m-jc-mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\005_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_29_jc_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\303_11_mc_mmn.cnt.npy
#  15/144 [==>...........................] - ETA: 5:02 - loss: 642564.1875 - root_mean_squared_error: 801.6010 - mean_absolute_error: 732.7368D:EEG Data\DDP Surfdrive\processed\488_11_jd_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\726-126-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\102_11_jr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\428_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_17_jr_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\745-466-23m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_23_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\104_35_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\726-126-41m-jr-mmn36.cnt.npy
#  16/144 [==>...........................] - ETA: 5:00 - loss: 628019.2500 - root_mean_squared_error: 792.4767 - mean_absolute_error: 724.5761D:EEG Data\DDP Surfdrive\processed\145_23_mr_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\036_11_mc_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\604-133-41m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\604-133-29m-jc-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\336_11_mc_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\002_29_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\325_11_mc_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\438_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_47_mr_mmn36_wk.cnt.npy
#  17/144 [==>...........................] - ETA: 4:57 - loss: 627968.4375 - root_mean_squared_error: 792.4446 - mean_absolute_error: 723.8786D:EEG Data\DDP Surfdrive\processed\730-201-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\471_29_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_23_mr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_11_mc_mmn_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_11_md_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_11_mr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_11_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\340_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\023_41_mc_mmn39_380_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_29_mc_mmn36_wk.cnt.npy
#  18/144 [==>...........................] - ETA: 4:54 - loss: 632923.1875 - root_mean_squared_error: 795.5647 - mean_absolute_error: 725.0128D:EEG Data\DDP Surfdrive\processed\332_11_jc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\630-372-11m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\717-111-29m-mr-mmn25-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\607-128-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_11_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\720-166-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\129_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\140_17_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\435_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\017_17_jc_mmn25_wk.cnt.npy
#  19/144 [==>...........................] - ETA: 4:54 - loss: 628986.1250 - root_mean_squared_error: 793.0864 - mean_absolute_error: 723.0807D:EEG Data\DDP Surfdrive\processed\148_17_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_17_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\493_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\491_11_jd_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\718-102-41m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_11_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_11_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_17_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\496_23_jc_mmn25_wk.cnt.npy
#  20/144 [===>..........................] - ETA: 4:53 - loss: 621235.8750 - root_mean_squared_error: 788.1852 - mean_absolute_error: 717.9207D:EEG Data\DDP Surfdrive\processed\306_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_23_jc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\632-399-11m-jc-mmn58-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\017_41_jc_mmn39_380_2_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\110_41_jr_mmn58.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\624-373-41m-mc-mmn3_9.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\033_17_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\475_41_jd_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\145_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\027_23_jc_mmn25_wk.cnt.npy
#  21/144 [===>..........................] - ETA: 4:53 - loss: 632559.6875 - root_mean_squared_error: 795.3362 - mean_absolute_error: 725.1071D:EEG Data\DDP Surfdrive\processed\115_35_mr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\140_17_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\170_23_mr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\708-073-41m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_11_mc_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\428_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\140_17_mr_mmn36_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\180_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_11_jr_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\130_29_jr_mmn36_wk.cnt.npy
#  22/144 [===>..........................] - ETA: 4:49 - loss: 633469.1875 - root_mean_squared_error: 795.9078 - mean_absolute_error: 725.9625D:EEG Data\DDP Surfdrive\processed\733-108-23m-jr-mmn36-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_35_mr_mmnbackward.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_23_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\004_29_mc_mmn25_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_35_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_29_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\620-313-11m-jc-mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\348_35_jc_mmn25_wk.cnt.npy
#  23/144 [===>..........................] - ETA: 4:46 - loss: 633222.1875 - root_mean_squared_error: 795.7526 - mean_absolute_error: 727.5468D:EEG Data\DDP Surfdrive\processed\434_11_jd_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_17_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_41_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_17_jr_bakdakrev.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_41_mc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_41_md_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_41_jc_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\325_11_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\346_23_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_11_md_mmn47_wk.cnt.npy
#  24/144 [====>.........................] - ETA: 4:44 - loss: 641377.1250 - root_mean_squared_error: 800.8602 - mean_absolute_error: 731.8127D:EEG Data\DDP Surfdrive\processed\122_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\428_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_41_md_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_29_mr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\029_17_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_47_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\018_11_mc_mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\168_23_jr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\017_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\749-032-29m-jr-mmn36.cnt.npy
#  25/144 [====>.........................] - ETA: 4:41 - loss: 646447.0000 - root_mean_squared_error: 804.0193 - mean_absolute_error: 734.4670D:EEG Data\DDP Surfdrive\processed\628-369-11m-mc-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\619-247-41m-mc-mmn39.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\348_35_jc_mmn6_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\730-201-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\719-079-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_11_jc_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\620-313-11m-jc-mmn3.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\328_41_jc_mmn36_wk.cnt.npy
#  26/144 [====>.........................] - ETA: 4:41 - loss: 646396.1250 - root_mean_squared_error: 803.9876 - mean_absolute_error: 734.8622D:EEG Data\DDP Surfdrive\processed\472_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\448_29_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\610-185-41m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\122_11_mr_mmn36_wk_mmn25_wk_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\168_41_jr_mmn39_1500_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\311_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\337_11_jc_mmn_25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\702-071-47m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\034_17_mc_mmn47_slp.cnt.npy
#  27/144 [====>.........................] - ETA: 4:38 - loss: 657922.9375 - root_mean_squared_error: 811.1245 - mean_absolute_error: 741.2468D:EEG Data\DDP Surfdrive\processed\122_23_jr_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_11_mr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\721-106-23m-mr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\001_29_jc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\303_17_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\749-032-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\109_35_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\609-158-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\632-399-11m-jc-mmn58-slp.cnt.npy
#  28/144 [====>.........................] - ETA: 4:35 - loss: 657307.8750 - root_mean_squared_error: 810.7452 - mean_absolute_error: 741.8575D:EEG Data\DDP Surfdrive\processed\014_41_mc_mmn39.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_17_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\637-479-23m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\168_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_29_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\133_23_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\481_11_jd_mmn_36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\712-074-23m-mr-mmn36dummy-mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_23_md_mmn25_wk.cnt.npy
#  29/144 [=====>........................] - ETA: 4:33 - loss: 654467.5000 - root_mean_squared_error: 808.9916 - mean_absolute_error: 740.8004D:EEG Data\DDP Surfdrive\processed\434_29_jd_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\304_11_mc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\607-128-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_41_mr_mmn39_380_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\317_29_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\726-126-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\034_41_mc_mmn39_380_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\449_23_jd_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\129_29_jr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\311_41_jc_mmn25_wk.cnt.npy
#  30/144 [=====>........................] - ETA: 4:30 - loss: 658189.5625 - root_mean_squared_error: 811.2888 - mean_absolute_error: 744.0449D:EEG Data\DDP Surfdrive\processed\040_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_11_jd_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\124_47_jr_mmn39_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\620-313-23m-jc-mmn25-mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\151_11_mr_mmn36_slp_mmn25_slp_mmn47_slp_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\617-289-23m-mc-mmn36-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\751-452-41m-jr-mmn39langz.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\301_41_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_17_jr_mmn25.cnt.npy
#  31/144 [=====>........................] - ETA: 4:26 - loss: 668220.6250 - root_mean_squared_error: 817.4476 - mean_absolute_error: 749.3057D:EEG Data\DDP Surfdrive\processed\702-071-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_47_jc_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\628-369-11m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\427_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\171_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\491_11_jd_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\424_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\731-197-23m-jr-mmn36dummy-waak.cnt.npy
#  32/144 [=====>........................] - ETA: 4:23 - loss: 669261.0000 - root_mean_squared_error: 818.0837 - mean_absolute_error: 749.8147D:EEG Data\DDP Surfdrive\processed\473_11_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\424_35_jd_mmn25_wk_.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\344_11_jc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\496_11_jd_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\317_23_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_29_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\104_11_jr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\604-133-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\444_11_md_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\613-176-23m-mc-mmn36-waak.cnt.npy
#  33/144 [=====>........................] - ETA: 4:21 - loss: 661414.9375 - root_mean_squared_error: 813.2742 - mean_absolute_error: 744.6707D:EEG Data\DDP Surfdrive\processed\107_29_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_11_jc_mmn58_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\009_17_jc_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\415_23_jd_mmn25_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\018_41_mc_mmn39_1500_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\433_41_jd_mmn36_mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\309_17_jc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\724-116-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\308_23_jc_mmn36_wk.cnt.npy
#  34/144 [======>.......................] - ETA: 4:19 - loss: 662532.1875 - root_mean_squared_error: 813.9608 - mean_absolute_error: 745.2095D:EEG Data\DDP Surfdrive\processed\466_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\348_11_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_11_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\617-289-23m-mc-mmn36-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\165_17_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\621-241-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\434_11_jd_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\015_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\721-106-41m-mr-mmn36.cnt.npy
#  35/144 [======>.......................] - ETA: 4:16 - loss: 657941.6875 - root_mean_squared_error: 811.1360 - mean_absolute_error: 742.6404D:EEG Data\DDP Surfdrive\processed\725-161-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\104_11_jr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\180_41_mr_mmn39_1500_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\434_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\004_29_mc_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_17_mr_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_11_jc_mmn58_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_23_md_mmn36.cnt.npy
#  36/144 [======>.......................] - ETA: 4:14 - loss: 662046.3125 - root_mean_squared_error: 813.6623 - mean_absolute_error: 745.0961D:EEG Data\DDP Surfdrive\processed\345_29_mc_mmnrev_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\701-008-41m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_11_jr_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\104_41_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\108_11_jr_mmn36_slp_mmn25_slp_mmn47_mixed_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_35_md_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\154_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\433_41_jd_mmn36_mix.cnt.npy
#  37/144 [======>.......................] - ETA: 4:12 - loss: 661847.3750 - root_mean_squared_error: 813.5400 - mean_absolute_error: 744.5576D:EEG Data\DDP Surfdrive\processed\108_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\758-465-29m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\152_11_jr_mmn_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_41_jc_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\451_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\448_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\029_17_mc_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\179_17_mr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\751-452-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\435_29_md_mmn36_wk.cnt.npy
#  38/144 [======>.......................] - ETA: 4:10 - loss: 664870.7500 - root_mean_squared_error: 815.3961 - mean_absolute_error: 746.8840D:EEG Data\DDP Surfdrive\processed\017_17_jc_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\496_11_jd_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\344_11_jc_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\455_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\412_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\408_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\019_17_mc_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_23_mr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\108_29_jr_mmn36_wk.cnt.npy
#  39/144 [=======>......................] - ETA: 4:07 - loss: 663424.5625 - root_mean_squared_error: 814.5088 - mean_absolute_error: 746.4006D:EEG Data\DDP Surfdrive\processed\122_23_jr_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\309_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\346_35_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\628-369-29m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_41_mc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_41_mc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_17_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\465_11_jd_mmn_36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\413_35_jd_mmn25_wk.cnt.npy
#  40/144 [=======>......................] - ETA: 4:05 - loss: 665545.9375 - root_mean_squared_error: 815.8100 - mean_absolute_error: 748.2456D:EEG Data\DDP Surfdrive\processed\340_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\004_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\702-071-47m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\107_11_mr_mmn36_wk_mmn25_wk_mmn47_wk_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\448_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\719-079-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\109_47_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\414_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_11_mr_mmn36_slp_mmn25_slp_mmn47_slp_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_41_jr_mmn39_1500.cnt.npy
#  41/144 [=======>......................] - ETA: 4:02 - loss: 671983.3125 - root_mean_squared_error: 819.7459 - mean_absolute_error: 751.6777D:EEG Data\DDP Surfdrive\processed\481_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\717-111-29m-mr-mmn36-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\152_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\019_17_mc_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\025_11_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\451_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\485_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\621-241-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_11_md_mmn58_wk.cnt.npy
#  42/144 [=======>......................] - ETA: 4:00 - loss: 672611.4375 - root_mean_squared_error: 820.1289 - mean_absolute_error: 752.8375D:EEG Data\DDP Surfdrive\processed\141_17_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\725-161-41m-jr-mmn36-2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\144_11_jr_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_35_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\445_29_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_23_mr_mmn36w.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_17_mr_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\610-185-29m-jc-mmn36-2-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\311_17_jc_mmn25_wk.cnt.npy
#  43/144 [=======>......................] - ETA: 3:58 - loss: 671915.1875 - root_mean_squared_error: 819.7043 - mean_absolute_error: 752.5784D:EEG Data\DDP Surfdrive\processed\342_23_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_29_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\428_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\145_23_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\455_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\733-108-jr-23m-mmn36-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\133_23_jr_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\429_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\011_29_jc_mmn36_2_wk.cnt.npy
#  44/144 [========>.....................] - ETA: 3:56 - loss: 672644.0625 - root_mean_squared_error: 820.1488 - mean_absolute_error: 754.0938D:EEG Data\DDP Surfdrive\processed\445_29_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\141_17_jr_mmn58.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\348_11_jc_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\744-352-29m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\457_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\110_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\457_29_jd_mmn25_wk.cnt.npy
#  45/144 [========>.....................] - ETA: 3:53 - loss: 673861.8750 - root_mean_squared_error: 820.8909 - mean_absolute_error: 755.0990D:EEG Data\DDP Surfdrive\processed\173_17_jr_mmn36_slp_3.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\009_23_jc_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\429_29_md_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_11_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\628-369-41m-mc-mmn39-2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_23_mr_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\636-468-23m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_17_jr_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\745-466-23m-mr-mmn36.cnt.npy
#  46/144 [========>.....................] - ETA: 3:51 - loss: 671399.5000 - root_mean_squared_error: 819.3896 - mean_absolute_error: 754.1244D:EEG Data\DDP Surfdrive\processed\009_17_jc_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\109_29_jd_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\337_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\335_11_mc_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\110_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\107_11_mr_mmn36_wk_mmn25_wk_mmn47_wk_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\173_17_jr_mmn36_slp_3.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_41_jc_mmn39_1500_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_17_mr_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\602-115-41m-mc-mmn36.cnt.npy
#  47/144 [========>.....................] - ETA: 3:48 - loss: 671556.5625 - root_mean_squared_error: 819.4855 - mean_absolute_error: 753.9233D:EEG Data\DDP Surfdrive\processed\639-484-11m-jc-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_17_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_23_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\751-452-41m-jr-mmn39langz.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\630-372-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\717-111-23m-mr-mmn36-dummy-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_35_md_mmn36_wk.cnt.npy
#  48/144 [=========>....................] - ETA: 3:45 - loss: 671212.9375 - root_mean_squared_error: 819.2758 - mean_absolute_error: 753.7025D:EEG Data\DDP Surfdrive\processed\177_41_jr_mmn39_1500_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\333_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_17_jc_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\722-135-23m-jr-mmn36-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\134_11_mr_mmn_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\165_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_35_mr_mmn36_2_wk.cnt.npy
#  49/144 [=========>....................] - ETA: 3:43 - loss: 672576.2500 - root_mean_squared_error: 820.1074 - mean_absolute_error: 754.7321D:EEG Data\DDP Surfdrive\processed\609-158-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\488_11_jd_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\618-163-23m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\179_23_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\438_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\102_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\165_11_jr_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_23_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\752-457-23m-jr-mmn36.cnt.npy
#  50/144 [=========>....................] - ETA: 3:41 - loss: 674308.5000 - root_mean_squared_error: 821.1628 - mean_absolute_error: 755.9080D:EEG Data\DDP Surfdrive\processed\616-240-11m-mc-mmn3.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\720-166-29m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_11_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\165_11_jr_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\455_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\451_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\018_11_mc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\148_17_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\627-356-23m-mc-mmn36.cnt.npy
#  51/144 [=========>....................] - ETA: 3:39 - loss: 666922.0625 - root_mean_squared_error: 816.6530 - mean_absolute_error: 751.0527D:EEG Data\DDP Surfdrive\processed\110_41_jr_mmn58.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_17_jc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\109_29_jd_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\118_29_mr_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\465_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_41_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\126_47_md_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\173-2_11_jr_mmn58.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\129_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\034_35_mc_mmn36_2_wk.cnt.npy
#  52/144 [=========>....................] - ETA: 3:36 - loss: 673319.1875 - root_mean_squared_error: 820.5602 - mean_absolute_error: 754.7507D:EEG Data\DDP Surfdrive\processed\133_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\491_41_jd_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\154_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\424_29_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\730-201-23m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\701-008-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\014_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\608-170-11m-mc-mmn36-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\621-241-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\730-201-23m-jr-mmn36.cnt.npy
#  53/144 [==========>...................] - ETA: 3:34 - loss: 677260.5000 - root_mean_squared_error: 822.9584 - mean_absolute_error: 757.5898D:EEG Data\DDP Surfdrive\processed\001_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\621-241-11m-jc-mmn2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\491_11_jd_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\126_11_mr_mmn2_25_wk_mmn47_wk_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\171_41_jr_mmn39_1500_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_3_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\333_29_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\173_11_jr_mmn25_wk_mmn36_wk_mmn47_wk_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\144_11_jr_mmn_36_slp_mmn25_slp_2.cnt.npy
#  54/144 [==========>...................] - ETA: 3:32 - loss: 676320.1875 - root_mean_squared_error: 822.3868 - mean_absolute_error: 756.6665D:EEG Data\DDP Surfdrive\processed\718-102-29m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_17_jr_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\015_11_jc_mmn36_slp_mmn25_slp_mmn47_slp_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\171_11_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\340_41_mc_mmn39_mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\317_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\448_29_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\133_23_jr_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_29_jr_mmn58_wk.cnt.npy
#  55/144 [==========>...................] - ETA: 3:30 - loss: 673657.6875 - root_mean_squared_error: 820.7665 - mean_absolute_error: 755.1152D:EEG Data\DDP Surfdrive\processed\346_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\317_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\438_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\637-479-23m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\722-135-23m-jr-mmn25-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_17_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\145_41_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\632-399-11m-jc-mmn58-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_29_mc_mmn25_wk.cnt.npy
#  56/144 [==========>...................] - ETA: 3:28 - loss: 674149.9375 - root_mean_squared_error: 821.0663 - mean_absolute_error: 755.8627D:EEG Data\DDP Surfdrive\processed\445_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\332_17_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\344_11_jc_mmn47_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_11_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\034_41_mc_mmn39_380_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\178_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\133_23_jr_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\018_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\343_35_mc_mmn25_wk.cnt.npy
#  57/144 [==========>...................] - ETA: 3:25 - loss: 674249.8125 - root_mean_squared_error: 821.1271 - mean_absolute_error: 756.0252D:EEG Data\DDP Surfdrive\processed\035_41_jc_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\705-050-23m-jr-mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\726-126-29m-jr-mmn36-1.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_11_jd_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\126_47_md_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\607-128-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\604-133-41m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_11_jc_mmn36_slp_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_17_mr_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\636-468-23m-jc-mmn36.cnt.npy
#  58/144 [===========>..................] - ETA: 3:22 - loss: 677395.0000 - root_mean_squared_error: 823.0400 - mean_absolute_error: 757.6681D:EEG Data\DDP Surfdrive\processed\178_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\154_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\705-050-47m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\168_41_jr_mmn39_1500_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_11_jr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_23_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\450_41_md_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\133_41_jr_mmn39.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\488_11_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\604-133-35-jc-kujala.cnt.npy
#  59/144 [===========>..................] - ETA: 3:19 - loss: 682825.8750 - root_mean_squared_error: 826.3328 - mean_absolute_error: 760.4965D:EEG Data\DDP Surfdrive\processed\733-108-23m-jr-mmn36-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_35_jd_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\730-201-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\317_29_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\105_35_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\742-421-29m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\304_17_mc_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\493_41_md_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\408_23_md_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_35_md_mmn25_wk.cnt.npy
#  60/144 [===========>..................] - ETA: 3:17 - loss: 685233.5625 - root_mean_squared_error: 827.7883 - mean_absolute_error: 762.5875D:EEG Data\DDP Surfdrive\processed\408_23_md_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\333_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_17_mc_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_35_jd_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\340_23_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\336_17_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_11_jc_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\107_41_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\408_41_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_17_mc_mmn36_wk.cnt.npy
#  61/144 [===========>..................] - ETA: 3:14 - loss: 685545.3750 - root_mean_squared_error: 827.9766 - mean_absolute_error: 762.8716D:EEG Data\DDP Surfdrive\processed\170_41_mr_mmn39_1500.cnt.npy
# ...
# D:EEG Data\DDP Surfdrive\processed\721-106-23m-mr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\427_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\408_29_md_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\015_11_jc_mmn36_slp_mmn25_slp_mmn47_slp_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\105_11_jr_mmn36_slp_mmn25_wk_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_41_md_mmn39.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\035_41_jc_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\154_17_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\133_23_jr_mmn47_wk.cnt.npy
# 100/144 [===================>..........] - ETA: 1:32 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\728-164-29m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\714-082-41m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\465_41_jd_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_17_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\752-457-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\150_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\337_11_jc_mmn_25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_17_mr_mmn47_slp.cnt.npy
# 101/144 [====================>.........] - ETA: 1:30 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\023_35_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\745-466-41m-mr-mmn39langzr.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_17_mr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\615-240-41m-mc-mmn39.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_17_jc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\145_11_mr_mmn36_slp_mmn25_slp_mmn47_mixed_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\169_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\332_17_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\604-133-23m-jc-mmn36-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\308_35_jc_mmn36_wk.cnt.npy
# 102/144 [====================>.........] - ETA: 1:28 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\429_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\493_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\340_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\610-185-11m-jc-mmn-rst.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\444_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\712-074-23m-mr-mmn36dummy-mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\627-356-23m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\346_17_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\708-073-23m-mr-mmn36-rst.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\325_23_mc_mmn36.cnt.npy
# 103/144 [====================>.........] - ETA: 1:26 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\343_35_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\408_35_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\701-008-41m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\033_17_mc_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_29_jr_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\608-170-11m-mc-mmn58-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\443_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\141_11_jr_mmn.cnt.npy
# 104/144 [====================>.........] - ETA: 1:24 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\178_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_29_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\494_11_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_11_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\036_11_mc_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_35_md_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\108_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\137_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\141_23_jr_mmn36_slp_3.cnt.npy
# 105/144 [====================>.........] - ETA: 1:22 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\025_29_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\162_17_mr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\481_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\433_35_jd_mmn36_mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\103_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_35_md_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\134_11_mr_mmn36_wk_mmn25_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\478_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\151_29_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\472_11_jd_mmn_25_wk.cnt.npy
# 106/144 [=====================>........] - ETA: 1:19 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\334_29_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_11_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\630-372-29m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\617-289-23m-mc-mmn25-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\149_23_mr_mmn36w.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\620-313-41-jc-mmn3_9.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_41_mc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\494_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\429_23_md_mmn25_wk.cnt.npy
# 107/144 [=====================>........] - ETA: 1:17 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\628-369-41m-mc-mmn39-2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\011_35_jc_mmn36_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\496_41_jd_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\002_23_jc_mmn36_wk_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\488_11_jd_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\488_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\340_11_mc_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\124_41_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\459_11_jd_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\345_11_mc_mmn36_slp.cnt.npy
# 108/144 [=====================>........] - ETA: 1:15 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\177_29_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\414_29_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\001_47_jc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\340_41_mc_mmn39_mix.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_41_md_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\027_11_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\141_29_jr_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\411_41_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\154_17_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\444_11_md_mmn36_slp.cnt.npy
# 109/144 [=====================>........] - ETA: 1:13 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\486_41_jd_mmn41_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\163_17_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\725-161-41m-jr-mmn36-2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\147_23_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_11_md_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\011_35_jc_mmn36_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\486_23_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\415_29_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\342_35_jc_mmn25_wk.cnt.npy
# 110/144 [=====================>........] - ETA: 1:11 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\721-106-23m-mr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\414_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\705-050-29m-jr-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\171_17_jr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\408_23_md_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\144_17_jr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\181_41_jr_mmn39_380.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\724-116-23m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\311_29_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\303_23_mc_mmn25_wk.cnt.npy
# 111/144 [======================>.......] - ETA: 1:09 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\345_11_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\303_11_mc_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\110_29_jr_mmn25_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\481_29_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\619-247-23m-mc-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\430_35_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\602-115-35m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\618-163-41m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\702-071-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\123_29_jr_mmn25_wk.cnt.npy
# 112/144 [======================>.......] - ETA: 1:07 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\168_23_jr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\471_29_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\705-050-47m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\126_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\742-421-23m-mr-mmn36-2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\712-074-23m-mr-mmn36-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\027_11_jc_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_11_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\311_35_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_11_md_mmn47_slp.cnt.npy
# 113/144 [======================>.......] - ETA: 1:05 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\313_17_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\414_11_jd_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\738-389-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\475_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_23_md_mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\311_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\449_11_jd_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\719-079-6m-jr-mmn-slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\014_35_mc_mmn36_2_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\435_35_md_mmn36_wk.cnt.npy
# 114/144 [======================>.......] - ETA: 1:02 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\333_17_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_23_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\170_11_mr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\040_29_jc_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\455_11_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\168_23_jr_mmn36_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\306_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\325_35_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\610-185-29m-jc-mmn36-2-waak.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\326_35_jc_mmn36_wk.cnt.npy
# 115/144 [======================>.......] - ETA: 1:00 - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\750-462-29m-mr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\115_29_mr_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\413_35_jd_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\039_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\325_11_mc_mmn36_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\313_17_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\118_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\430_23_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\118_23_mr_mmn36_wk_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\009_29_jc_mmn36_wk.cnt.npy
# 116/144 [=======================>......] - ETA: 58s - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nan D:EEG Data\DDP Surfdrive\processed\414_35_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\754-472-23m-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\705-050-41m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\612-486-41m-jc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\124_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\023_11_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\429_29_md_mmn_36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\491_11_jd_mmn58.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\110_17_jr_mmn.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_29_jr_mmn36_wk.cnt.npy
# 117/144 [=======================>......] - ETA: 56s - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\308_23_jc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\308_23_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\473_41_md_mmn39_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\466_11_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\482_23_md_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\102_47_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\337_11_jc_mmn_25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\301_35_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\343_35_mc_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\320_29_jc_mmn25_wk.cnt.npy
# 118/144 [=======================>......] - ETA: 54s - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\011_23_jc_mmn25_2.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\469_11_md_mmn58_slp.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\180_35_mr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_11_jr_mmn47_mixed.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\637-479-23m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\751-452-29m-jr-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\171_11_jr_mmn36_wk_mmn25_wk_mmn47_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\474_11_md_mmn58_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\182_17_jr_mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\403_35_jd_mmn25_wk.cnt.npy
# 119/144 [=======================>......] - ETA: 52s - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\332_41_jc_mmn39_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\177_41_jr_mmn39_1500_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\334_35_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\487_35_md_mmn25_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\002_29_jc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\144_35_jr_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\616-240-23m--mc-mmn25.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\448_23_jd_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\602-115-35m-mc-mmn36.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\628-369-41m-mc-mmn39-2.cnt.npy
# 120/144 [========================>.....] - ETA: 50s - loss: nan - root_mean_squared_error: nan - mean_absolute_error: nanD:EEG Data\DDP Surfdrive\processed\304_23_mc_mmn36_wk.cnt.npy
# D:EEG Data\DDP Surfdrive\processed\104_47_jr_mmn36_wk.cnt.npy
